# %%
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.neighbors import LocalOutlierFactor

# %%
file_path = "final_filtered.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#       TIMESTAMP  ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  \
# 0  1.502903e+12                 80.0         33.3      1009.0
# 1  1.502903e+12                 80.0         32.5      1003.0
# 2  1.502903e+12                 80.0         32.9       995.0
# 3  1.502903e+12                 80.0         32.5      1004.0
# 4  1.502903e+12                 80.0         32.9      1005.0
#
#    AIR_INTAKE_TEMP  SPEED  THROTTLE_POS  Efficiency
# 0             59.0    0.0            25    6.666667
# 1             59.0    0.0            25    6.666667
# 2             59.0    0.0            25    6.666667
# 3             60.0    0.0            25    6.666667
# 4             60.0    0.0            25    6.666667

# %%
def remove_outliers(column):
    mean = column.mean()
    std = column.std()
    lower_bound = mean - 3 * std
    upper_bound = mean + 3 * std
    return column[(column >= lower_bound) & (column <= upper_bound)]

# %%
columns_to_process = ['ENGINE_COOLANT_TEMP', 'ENGINE_RPM', 'AIR_INTAKE_TEMP', 'SPEED']
for col in columns_to_process:
    df[col] = remove_outliers(df[col])

# %%
columns_to_exclude = ['TIMESTAMP']
df_subset = df.drop(columns_to_exclude, axis=1)

# %%
timestamp = df["TIMESTAMP"]
type(timestamp)
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#       TIMESTAMP  ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  \
# 0  1.502903e+12                 80.0         33.3      1009.0
# 1  1.502903e+12                 80.0         32.5      1003.0
# 2  1.502903e+12                 80.0         32.9       995.0
# 3  1.502903e+12                 80.0         32.5      1004.0
# 4  1.502903e+12                 80.0         32.9      1005.0
#
#    AIR_INTAKE_TEMP  SPEED  THROTTLE_POS  Efficiency
# 0             59.0    0.0            25    6.666667
# 1             59.0    0.0            25    6.666667
# 2             59.0    0.0            25    6.666667
# 3             60.0    0.0            25    6.666667
# 4             60.0    0.0            25    6.666667

# %%
df_subset.head()
# Out:
#    ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  AIR_INTAKE_TEMP  SPEED  \
# 0                 80.0         33.3      1009.0             59.0    0.0
# 1                 80.0         32.5      1003.0             59.0    0.0
# 2                 80.0         32.9       995.0             59.0    0.0
# 3                 80.0         32.5      1004.0             60.0    0.0
# 4                 80.0         32.9      1005.0             60.0    0.0
#
#    THROTTLE_POS  Efficiency
# 0            25    6.666667
# 1            25    6.666667
# 2            25    6.666667
# 3            25    6.666667
# 4            25    6.666667

# %%
std = df_subset.std().values

# %%
std
# Out:
# array([7.28667889e+08, 3.79782967e+00, 1.23868134e+01, 4.80872755e+02,
#        8.51096883e+00, 2.05221475e+01, 5.13938795e+00, 1.30940277e+00])

# %%
mean = df_subset.mean().values

# %%
mean
# Out:
# array([  80.58619375,   31.47844156, 1548.6972067 ,   39.70836473,
#          27.66864564,   27.72653061,    5.07977737])

# %%
df_subset.head()
# Out:
#    ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  AIR_INTAKE_TEMP  SPEED  \
# 0                 80.0         33.3      1009.0             59.0    0.0
# 1                 80.0         32.5      1003.0             59.0    0.0
# 2                 80.0         32.9       995.0             59.0    0.0
# 3                 80.0         32.5      1004.0             60.0    0.0
# 4                 80.0         32.9      1005.0             60.0    0.0
#
#    THROTTLE_POS  Efficiency
# 0            25    6.666667
# 1            25    6.666667
# 2            25    6.666667
# 3            25    6.666667
# 4            25    6.666667

# %%
for index, row in df_subset.iterrows():
  coolant_temp_eff = ((abs(mean[0]-row["ENGINE_COOLANT_TEMP"]))/mean[0])*100*0.25
  engine_load_eff = (abs(mean[1]-row["ENGINE_LOAD"])/mean[1])*100*0.1
  engine_rpm_eff = (abs(mean[2]-row["ENGINE_RPM"])/mean[2])*100*0.2
  air_int_eff = (abs(mean[3]-row["AIR_INTAKE_TEMP"])/mean[3])*100*0.1
  speed_eff = (abs(mean[4]-row["SPEED"])/mean[4])*100*0.05
  throttle_eff = (abs(mean[5]-row["THROTTLE_POS"])/mean[5])*100*0.3
  efficiency = coolant_temp_eff + engine_load_eff + engine_rpm_eff + air_int_eff + speed_eff + throttle_eff
  df_subset.at[index, "Efficiency"] = efficiency

# %%
df_subset.tail()
# Out:
#       ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  AIR_INTAKE_TEMP  SPEED  \
# 2690                 81.0         24.7      1154.0             48.0   14.0
# 2691                 81.0         27.1      1449.0             49.0   20.0
# 2692                 81.0         16.1      1539.0             50.0   12.0
# 2693                 82.0         41.2      1100.0             51.0   15.0
# 2694                 82.0         28.6      1122.0             51.0    5.0
#
#       THROTTLE_POS  Efficiency
# 2690            24   15.969171
# 2691            26    8.400674
# 2692            23   15.676367
# 2693            31   17.996308
# 2694            25   16.753607

# %%
coolant_temp_eff = ((mean[0]-std[0])/mean[0])*100*0.25
engine_load_eff = ((mean[1]-std[1])/mean[1])*100*0.1
engine_rpm_eff = ((mean[2]-std[2])/mean[2])*100*0.2
air_int_eff = ((mean[3]-std[3])/mean[3])*100*0.1
speed_eff = ((mean[4]-std[4])/mean[4])*100*0.05
throttle_eff = ((mean[5]-std[5])/mean[5])*100*0.3

# %%
efficiency = coolant_temp_eff + engine_load_eff + engine_rpm_eff + air_int_eff + speed_eff + throttle_eff

# %%
print(efficiency)
# Out:
# 77.2640432238995

# %%
print(df_subset["Efficiency"].unique())
# Out:
# [10.82197998 10.64532228 10.87570601 ... 10.49275587  5.22526273
#  11.06632379]

# %%
df_subset = pd.concat([timestamp.to_frame(), df_subset], axis=1)

# %%
df_subset.head()
# Out:
#       TIMESTAMP  ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  \
# 0  1.502903e+12                 80.0         33.3      1009.0
# 1  1.502903e+12                 80.0         32.5      1003.0
# 2  1.502903e+12                 80.0         32.9       995.0
# 3  1.502903e+12                 80.0         32.5      1004.0
# 4  1.502903e+12                 80.0         32.9      1005.0
#
#    AIR_INTAKE_TEMP  SPEED  THROTTLE_POS  Efficiency
# 0             59.0    0.0            25   20.538641
# 1             59.0    0.0            25   20.361983
# 2             59.0    0.0            25   20.592367
# 3             60.0    0.0            25   20.600905
# 4             60.0    0.0            25   20.715062

# %%
df_subset.to_csv("final_eff_data.csv", index=False)
